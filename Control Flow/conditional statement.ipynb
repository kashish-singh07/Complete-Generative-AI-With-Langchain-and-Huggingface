# %% [markdown]
# Conditional Statements(if,elif,else)

# %% [markdown]
# Conditional statements in Python are used to execute specific blocks of code based on whether a condition is true or false, allowing the program to make decisions and control its flow. The primary keywords used are if, elif, and else.
#
#
# Types of Conditional Statements
#
# if statement:
#
#  The simplest form, which runs a code block only if its condition is True.

# %%
age = 20
if age >= 18:
    print("You are an adult.") # This code is indented
# Out:
# You are an adult.

# %% [markdown]
# if-else statement:
#
#  Provides an alternative block of code to run if the if condition is False.

# %%
number = -5
if number > 0:
    print("The number is positive.")
else:
    print("The number is negative or zero.")
# Out:
# The number is negative or zero.

# %% [markdown]
# if-elif-else statement:
#
#  Used to check multiple conditions sequentially. Python stops checking as soon as it finds a True condition and executes the corresponding block.

# %%
score = 70
if score >= 90:
    print("Grade: A")
elif score >= 80:
    print("Grade: B")
elif score >= 70:
    print("Grade: C")
else:
    print("Grade: F")
# Out:
# Grade: C

# %%
##nested condition statement
num=int(input("Enter the number"))
if num>0:
    print("The number is positive")
    if num%2==0:
        print("The  number is even")
    else:
        print("The number is odd")
else:
    print("The number is zero or negatiive")
# Out:
# The number is positive
# The  number is even

# %%
##practical emaxple
year=int(input("Enter the year"))
if year%4==0:
    if year%100==0:
        if year%400==0:
            print(year,"is a leap year")
        else:
            print(year,"is not a leap year")
    else:
        print(year,"is a leap  year")
else:
    print(year,"is not a leap year")
# Out:
# 2026 is not a leap year

# %%
##Determine the ticket price based on age and whether the person is student
age = int(input("Enter your agre"))
is_student=input("Are you a student? (yes/no): ").lower()

if age<5:
    price = "Free"
elif age <= 12:
    price = "$10"
elif age <=17:
    if is_student=="yes":
        price = "$12"
    else:
        price = "$15"
elif age <=64:
    price = "$18"
else:
    price = "$20"
print("Ticket Price:", price)
# Out:
# Ticket Price: $18
